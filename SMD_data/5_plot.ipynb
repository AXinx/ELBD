# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = ['IForest','KNN','LOF','OCSVM','Ensemble']
#org_means = (0.8563, 0.8439, 0.5009, 0.8573, 0.8602)
#org_err = [0,0,0,0,0]


mlp_means = (0.6095, 0.5928, 0.4755, 0.5943, 0.7481)
mlp_err = [0.0149, 0.0186, 0.0002, 0.0099, 0.0189]

fig, ax = plt.subplots(figsize=(10,7))
#ax.scatter(x,org_means)
#ax.errorbar(x,org_means,yerr=org_err, label='NoMLP')
#ax.scatter(x,mlp_means)
ax.bar(x,mlp_means,width=0.3,yerr=mlp_err,label='WithMLP')
#ax.errorbar(x,mlp_means,yerr=mlp_err, label='WithMLP')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Detection methods', fontsize='x-large')
ax.set_ylabel('F1 score', fontsize='x-large')
ax.legend(loc='upper left', fontsize=12)
plt.savefig('Methods_Ensemble_MLP.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = ['IForest','KNN','LOF','OCSVM','Ensemble']
train_means = (196.2584, 224.9652, 201.5541, 190.1471, 187.3127)
train_err = [5.0364, 8.5842, 9.8963, 0.8252, 9.0857]

test_means = (148.2747, 148.3318, 148.26, 148.2515, 148.1793)
test_err = [0.0592, 0.1017, 0.0301, 0.0118, 0.0277]

fig, ax = plt.subplots(figsize=(10,7))
ax.scatter(x,train_means)
ax.errorbar(x,train_means,yerr=train_err, label='Train time')
ax.scatter(x,test_means)
ax.errorbar(x,test_means,yerr=test_err, label='Test time')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Detection methods', fontsize='x-large')
ax.set_ylabel('Time(s)', fontsize='x-large')
ax.legend(loc='upper right', fontsize=12)
plt.savefig('Train_Test_Time.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x = ['KNN','Ensemble_max','Ensemble_avg','Ensemble_w_avg','Deep_ensemble']
#org_means = (0.8563, 0.8439, 0.5009, 0.8573, 0.8602)
#org_err = [0,0,0,0,0]

mlp_means = (0.6127, 0.6132, 0.5991, 0.6231, 0.7481)
mlp_err = [0, 0, 0, 0, 0.0189]

fig, ax = plt.subplots(figsize=(10,7))
#ax.scatter(x,org_means)
#ax.errorbar(x,org_means,yerr=org_err, label='NoMLP')
rects = ax.bar(x,mlp_means,width=0.4)#,yerr=mlp_err)
#ax.errorbar(x,mlp_means,yerr=mlp_err, label='WithMLP')

for rect in rects:
    ax.text(rect.get_x()+0.05, rect.get_height(), rect.get_height(), ha='left', va='bottom')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Detection methods', fontsize='x-large')
ax.set_ylabel('F1 score', fontsize='x-large')
ax.set_ylim(0.1,0.8)
#ax.legend(loc='upper left', fontsize=12)
#plt.grid(axis="y")
plt.savefig('base-ensemble.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


x = ['KNN','Ensemble_max','Ensemble_avg','Ensemble_w_avg','Deep_ensemble']
#train_means = (17.4066, 16.2012, 15.842, 18.7639, 18.5348)
#train_err = [0.9753,0.5432,0.348,1.841,2.0759]

test_means = (14.8825, 52.2201, 52.2205, 52.5264, 148.1793)
test_err = [0.9507,1.5694,1.5694,1.5691,0.0277]

fig, ax = plt.subplots(figsize=(10,7))
#ax.scatter(x,train_means)
#ax.errorbar(x,train_means,yerr=train_err, label='Train time')
ax.scatter(x,test_means)
ax.errorbar(x,test_means,yerr=test_err)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Detection methods', fontsize='x-large')
ax.set_ylabel('Time(s)', fontsize='x-large')
#ax.legend(loc='center right', fontsize=12)
plt.savefig('Train_Test_Time.pdf')
plt.show()

# %% [markdown]
# ## Exp2

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

labels = ['IForest_MLP','KNN_MLP','LOF_MLP','OCSVM_MLP','Deep ensemble']
#org_means = (0.8563, 0.8439, 0.5009, 0.8573, 0.8602)
#org_err = [0,0,0,0,0]

mlp_means_d = (0.8573, 0.8581, 0.4181, 0.8557, 0.8923)
mlp_err_d = [0.0015, 0.0006, 0.0001, 0.0002, 0.0076]

mlp_means_s = (0.7227, 0.5105, 0.4752, 0.5918, 0.8025)
mlp_err_s = [0.0101, 0.0128, 0.0001, 0.0173, 0.0133]

width=0.4
x = np.arange(len(labels))

fig, ax = plt.subplots(figsize=(10,7))
#ax.scatter(x,org_means)
#ax.errorbar(x,org_means,yerr=org_err, label='NoMLP')
rects1 = ax.bar(x-width/2,mlp_means_d, width, label='DApp monitor data',yerr=mlp_err_d)
rects2 = ax.bar(x+width/2,mlp_means_s, width, label='SMD data',yerr=mlp_err_s)
#ax.errorbar(x,mlp_means,yerr=mlp_err, label='WithMLP')

for rect in rects1:
    ax.text(rect.get_x()+0.05, rect.get_height()+0.01, rect.get_height(), ha='left', va='bottom')
for rect in rects2:
    ax.text(rect.get_x()+0.05, rect.get_height()+0.01, rect.get_height(), ha='left', va='bottom')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_xlabel('Detection methods', fontsize='x-large')
ax.set_ylabel('F1 score', fontsize='x-large')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(0,1.2)
ax.legend(loc='upper left', fontsize=12)
#plt.grid(axis="y")
plt.savefig('base-mlp.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


x = ['IForest_MLP','KNN_MLP','LOF_MLP','OCSVM_MLP','Deep ensemble']
#train_means = (17.4066, 16.2012, 15.842, 18.7639, 18.5348)
#train_err = [0.9753,0.5432,0.348,1.841,2.0759]

test_means_d = (1.7406, 1.7224, 1.7169, 1.7552, 1.6869)
test_err_d = [0.0462, 0.0139, 0.002, 0.0364, 0.0219]

test_means_s = (27.4017, 27.3682, 27.3548, 27.3855, 27.2668)
test_err_s = [0.0996, 0.0055, 0.0072, 0.0974, 0.0068]

fig, ax1 = plt.subplots(figsize=(10,7))
#ax.scatter(x,train_means)
#ax.errorbar(x,train_means,yerr=train_err, label='Train time')
ax1.scatter(x,test_means_d)
ax1.errorbar(x,test_means_d,yerr=test_err_d, ecolor='k', marker='v', fmt='o', ms=15, mfc='white', mec='r', label='DApp monitoring data')

ax1.set_xlabel('Detection methods', fontsize='x-large')
ax1.set_ylabel('Time for DApp monitoring data(s)', fontsize='x-large')
ax1.set_ylim(1.5,2)
ax1.legend(loc='upper left', fontsize=12)

# ax.scatter(labels,corr_means, marker='o', c='', edgecolors='white')
# ax.errorbar(x-width,corr_means,yerr=corr_err, ecolor='k', marker='o', fmt='o', ms=15, mfc='white', mec='r', label='Correlation analysis')
# #ax.scatter(x,pca_means, marker='v')
# ax.errorbar(x,pca_means,yerr=pca_err, marker='v', fmt='o', ecolor='k', ms=15, mfc='white', mec='b', label='PCA')
# #ax.scatter(x+width,all_means, marker='s')
# ax.errorbar(x+width,all_means,yerr=all_err, marker='s', fmt='o', ecolor='k', ms=15, mfc='white', mec='g', label='No metrics selection')


ax2 = ax1.twinx()

ax2.scatter(x,test_means_s, c='y')
ax2.errorbar(x,test_means_s,yerr=test_err_s, c='y', marker='s', fmt='o', ecolor='k', ms=15, mfc='white', mec='g', label='SMD data')
ax2.set_ylabel('Time for SMD data(s)', fontsize='x-large')
ax2.set_ylim(20, 30)
ax2.legend(loc='upper right', fontsize=12)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#ax.set_xlabel('Detection methods', fontsize='x-large')
#ax.set_ylabel('Time(s)', fontsize='x-large')

#ax2.legend(loc='upper left', fontsize=12)
plt.savefig('time-base-mlp1.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


x = ['IForest_MLP','KNN_MLP','LOF_MLP','OCSVM_MLP','Deep ensemble']
#train_means = (17.4066, 16.2012, 15.842, 18.7639, 18.5348)
#train_err = [0.9753,0.5432,0.348,1.841,2.0759]

test_means_d = (1.7406, 1.7224, 1.7169, 1.7552, 1.6869)
test_err_d = [0.0462, 0.0139, 0.002, 0.0364, 0.0219]

test_means_s = (27.4017, 27.3682, 27.3548, 27.3855, 27.2668)
test_err_s = [0.0996, 0.0055, 0.0072, 0.0974, 0.0068]

fig, ax1 = plt.subplots(figsize=(10,7))
#ax.scatter(x,train_means)
#ax.errorbar(x,train_means,yerr=train_err, label='Train time')
ax1.scatter(x,test_means_d)
ax1.errorbar(x,test_means_d,yerr=test_err_d, label='DApp monitoring data')

ax1.set_xlabel('Detection methods', fontsize='x-large')
ax1.set_ylabel('Time for DApp monitoring data(s)', fontsize='x-large')
ax1.set_ylim(1.5,2)
ax1.legend(loc='upper left', fontsize=12)


ax2 = ax1.twinx()

ax2.scatter(x,test_means_s, c='y')
ax2.errorbar(x,test_means_s,yerr=test_err_s, c='y', label='SMD data')
ax2.set_ylabel('Time for SMD data(s)', fontsize='x-large')
ax2.set_ylim(20, 30)
ax2.legend(loc='upper right', fontsize=12)

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
#ax.set_xlabel('Detection methods', fontsize='x-large')
#ax.set_ylabel('Time(s)', fontsize='x-large')

#ax2.legend(loc='upper left', fontsize=12)
plt.savefig('time-base-mlp-2.pdf')
plt.show()
